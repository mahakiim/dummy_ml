# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy import stats
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import QuantileTransformer, RobustScaler, PowerTransformer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, f1_score, mean_absolute_error, mean_squared_error, classification_report

# %%
df = pd.read_csv('D:\dummyML\data\polder_data_fix.csv')
df.head()
# Out:
# <>:1: SyntaxWarning:
#
# invalid escape sequence '\d'
#
# <>:1: SyntaxWarning:
#
# invalid escape sequence '\d'
#
# C:\Users\UsHER\AppData\Local\Temp\ipykernel_3804\325939391.py:1: SyntaxWarning:
#
# invalid escape sequence '\d'
#              timestamp  Debit_Cipalasari  Debit_Hilir  Debit_Hulu Pump1 Pump2  \
# 0  2025-06-09 00:00:00          0.466032     2.389919    1.819317    on    on
# 1  2025-06-09 00:02:27          0.470409     2.398388    1.836405    on    on
# 2  2025-06-09 00:07:27          0.479342     2.415673    1.871278    on    on
# 3  2025-06-09 00:12:27          0.488275     2.432957    1.906150    on    on
# 4  2025-06-09 00:17:27          0.497208     2.450241    1.941023    on    on
#
#   Pump3  TMA_Cipalasari  TMA_Citarum  TMA_Kolam  bojongsoang  dayeuhkolot  \
# 0   off        0.634561     6.569780  12.875024          0.0          0.0
# 1   off        0.629908     6.559635  12.874414          0.0          0.0
# ...

# %%
for col in df.columns:
    print(f"- {col}")
# Out:
# - timestamp
# - Debit_Cipalasari
# - Debit_Hilir
# - Debit_Hulu
# - Pump1
# - Pump2
# - Pump3
# - TMA_Cipalasari
# - TMA_Citarum
# - TMA_Kolam
# - bojongsoang
# - dayeuhkolot
# - pintu
# - pump_on
# - status_banjir

# %%
drop_columns = ['timestamp', 'pump_on', 'pintu', 'status_banjir']
existing_drop_columns = [col for col in drop_columns if col in df.columns]
df.drop(columns=existing_drop_columns, inplace=True)

for col in df.columns:
    print(f"- {col}")
# Out:
# - Debit_Cipalasari
# - Debit_Hilir
# - Debit_Hulu
# - Pump1
# - Pump2
# - Pump3
# - TMA_Cipalasari
# - TMA_Citarum
# - TMA_Kolam
# - bojongsoang
# - dayeuhkolot

# %%
import pandas as pd
import joblib

# Muat model
model = joblib.load('D:\dummyML\data\DT_model.pkl')  # Sesuaikan path

# Contoh nilai manual
nilai_input = {
    'Debit_Cipalasari_norm': 0.2,
    'Debit_Hilir_norm': 0.4,
    'Debit_Hulu_norm': 0.3,
    'TMA_Cipalasari_norm': 0.5,
    'TMA_Citarum_norm': 0.4,
    'TMA_Kolam_norm': 0.9,
    # 'bojongsoang': 2.1,
    # 'dayeuhkolot': 1.8
}

# Buat DataFrame dan prediksi
df_input = pd.DataFrame([nilai_input])

# If model is a pipeline, this will work:
try:
    prediksi_numeric = model.predict(df_input)[0]
except ValueError as e:
    print("Error:", e)
    print("Pastikan model yang dimuat adalah pipeline yang mencakup preprocessing.")
    raise

mapping = {0: 'AMAN', 1: 'SIAGA1', 2: 'SIAGA2', 3: 'SIAGA3'}
print(f"Hasil prediksi: {mapping[prediksi_numeric]}")
# Out:
# Hasil prediksi: SIAGA3
# <>:5: SyntaxWarning: invalid escape sequence '\d'
# <>:5: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\UsHER\AppData\Local\Temp\ipykernel_12820\3152323586.py:5: SyntaxWarning: invalid escape sequence '\d'
#   model = joblib.load('D:\dummyML\data\DT_model.pkl')  # Sesuaikan path
